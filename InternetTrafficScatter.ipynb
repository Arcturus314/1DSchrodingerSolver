# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,4))
inputList = [
    1984,15,1985,33,1986,65,1987,128,1988,252,1989,498,1990,1000,1991,2002,1992,4444,1993,8715,1994,25830,1995,150500,
    1996,1200000,1997,5000000,1998,11200000,1999,25500000,2000,75250000,2001,175000000,2002,356000000,2003,681050000,
    2004,1267800000,2005,1802745619,2006,2910579371,2007,4477367718,2008,6491159470,2009,9301984735,2010,13751003569,
    2011,19974008812,2012,26214897380,2013,32798830927,2014,42423169029]

#from https://blogs.cisco.com/sp/the-history-and-future-of-internet-traffic

years     = []
trafficgb = []

for i in range(int(len(inputList)/2)):
    years.append(inputList[2*i])
    trafficgb.append(inputList[2*i+1])
    
print(years)
print(trafficgb)

plt.scatter(years,trafficgb,marker="+", color='black')
plt.plot(years,trafficgb, color='black', alpha=0.3)
plt.title("Historical Total Internet Traffic")
plt.xlabel("Year")
plt.ylabel("Total Monthly Traffic (GB)")
plt.yscale('log')
plt.show()
# Out:
# [1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]
# [15, 33, 65, 128, 252, 498, 1000, 2002, 4444, 8715, 25830, 150500, 1200000, 5000000, 11200000, 25500000, 75250000, 175000000, 356000000, 681050000, 1267800000, 1802745619, 2910579371, 4477367718, 6491159470, 9301984735, 13751003569, 19974008812, 26214897380, 32798830927, 42423169029]
